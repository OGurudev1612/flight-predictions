# %%
import pandas as pd

# %%
import os
def process_weather_data(file_path):
    flight_data = pd.read_csv(file_path)
    # Convert the timestamp to a pandas datetime object
    datetime_obj = pd.to_datetime(flight_data['timestamp_local'])

    # Extract the airport code from the file name
    airport_code = os.path.basename(file_path).split('_')[0].upper()

    # Extract the hour and minute components
    flight_data['Date'] = datetime_obj.dt.strftime('%m/%d/%Y')
    #pred_data['Date'] = datetime_obj.dt.strftime('%m/%d/%Y')
    flight_data['hours'] = datetime_obj.dt.hour

    columns_to_drop = ['app_temp', 'dhi', 'dni', 'ghi', 'pod', 'slp', 'solar_rad', 'datetime', 'timestamp_local', 'timestamp_utc', 'ts', 'uv', 'weather.icon']
    flight_data.drop(columns=columns_to_drop, inplace=True)
    file_name = os.path.basename(file_path)
    if 'syr' in file_name.lower():
        # flight_data = flight_data.rename(columns={'minutes': 'minutes', 'hour': 'hours'})
        flight_data.columns = flight_data.columns.map(lambda x: 'arr_' + str(x))
        flight_data.rename(columns={'arr_Date': 'Date'}, inplace=True)
    else:
        # flight_data = flight_data.rename(columns={'minutes': 'dep_minutes', 'hour': 'dep_hours'})
        flight_data['Origin_Airport'] = airport_code
        flight_data.columns = flight_data.columns.map(lambda x: 'dep_' + str(x))
        flight_data.rename(columns={'dep_Date': 'Date', 'dep_Origin_Airport': 'Origin_Airport'}, inplace=True)
    
    return flight_data

# %%
# List of file paths

# file_paths = ['data_miner/data/SYR_weather_data_forecast.csv', 'data_miner/data/JFK_weather_data_forecast.csv', 
#              'data_miner/data/MCO_weather_data_forecast.csv', 'data_miner/data/ORD_weather_data_forecast.csv']
file_paths = ['data_miner/data/SYR_weather_data_hourly.csv', 'data_miner/data/JFK_weather_data_hourly.csv', 
              'data_miner/data/MCO_weather_data_hourly.csv', 'data_miner/data/ORD_weather_data_hourly.csv']

for file in file_paths:
    processed_data = process_weather_data(file)
    file_name = os.path.basename(file)
    file_name_no_ext, file_ext = os.path.splitext(file_name)
    new_file_name = f'{file_name_no_ext}_processed.csv'
    print(processed_data.head())
    processed_data.to_csv(f'weather_data/{new_file_name}', index=False)
    print(len(processed_data.columns))
# Out:
#    arr_azimuth  arr_clouds  arr_dewpt  arr_elev_angle  arr_h_angle  \
# 0        260.9         100       -2.3           -24.9          NaN
# 1        270.7         100       -3.0           -35.8          NaN
# 2        282.1         100       -4.0           -46.6          NaN
# 3        297.0         100       -4.4           -56.9          NaN
# 4        319.8         100       -4.4           -65.6          NaN
#
#    arr_precip  arr_pres arr_revision_status  arr_rh  arr_snow  arr_temp  \
# 0         0.0       987               final      78       0.0       1.1
# 1         0.0       987               final      77       0.0       0.6
# 2         0.0       986               final      71       0.0       0.6
# 3         0.0       987               final      69       0.0       0.6
# 4         0.0       986               final      69       0.0       0.6
#
#    arr_vis arr_weather.description  arr_weather.code  arr_wind_dir  \
# 0       14         Overcast clouds               804           240
# 1       16         Overcast clouds               804           240
# 2       16         Overcast clouds               804           240
# 3       16         Overcast clouds               804           250
# 4       14         Overcast clouds               804           250
#
#    arr_wind_gust_spd  arr_wind_spd        Date  arr_hours
# 0                9.6          4.59  12/31/2019         19
# 1                9.6          4.59  12/31/2019         20
# 2               10.4          5.70  12/31/2019         21
# 3               10.4          6.20  12/31/2019         22
# 4               10.8          6.20  12/31/2019         23
# 19
#    dep_azimuth  dep_clouds  dep_dewpt  dep_elev_angle  dep_h_angle  \
# 0        261.2         100        3.8           -26.2          NaN
# 1        270.5         100        3.9           -37.5          NaN
# 2        281.4         100        3.7           -48.8          NaN
# 3        296.3         100        1.6           -59.6          NaN
# 4        320.8         100        0.7           -68.6          NaN
#
#    dep_precip  dep_pres dep_revision_status  dep_rh  dep_snow  dep_temp  \
# 0        0.00      1002               final      88       0.0       5.6
# 1        0.25      1003               final      85       0.0       6.3
# 2        0.00      1003               final      82       0.0       6.5
# 3        0.00      1002               final      73       0.0       6.1
# 4        0.00      1003               final      69       0.0       6.0
#
#    dep_vis dep_weather.description  dep_weather.code  dep_wind_dir  \
# 0       16         Overcast clouds               804           220
# 1       16         Overcast clouds               804           220
# 2       16         Overcast clouds               804           255
# 3       16         Overcast clouds               804           270
# 4       16         Overcast clouds               804           270
#
#    dep_wind_gust_spd  dep_wind_spd        Date  dep_hours Origin_Airport
# 0                6.0          3.60  12/31/2019         19            JFK
# 1                6.8          5.37  12/31/2019         20            JFK
# 2                8.0          7.45  12/31/2019         21            JFK
# 3                9.3          6.70  12/31/2019         22            JFK
# 4               10.4          7.45  12/31/2019         23            JFK
# 20
#    dep_azimuth  dep_clouds  dep_dewpt  dep_elev_angle  dep_h_angle  \
# 0        252.7          25        6.5           -17.3          NaN
# 1        258.4          50        7.1           -30.1          NaN
# 2        264.1          87        8.8           -43.1          NaN
# 3        270.5           0        8.1           -56.3          NaN
# 4        280.1           0        7.0           -69.4          NaN
#
#    dep_precip  dep_pres dep_revision_status  dep_rh  dep_snow  dep_temp  \
# 0         0.0      1014               final      53         0      16.1
# 1         0.0      1014               final      55         0      16.1
# 2         0.0      1015               final      69         0      14.4
# 3         0.0      1015               final      68         0      13.9
# 4         0.0      1015               final      63         0      13.9
#
#    dep_vis dep_weather.description  dep_weather.code  dep_wind_dir  \
# 0       16        Scattered clouds               802           270
# 1       16           Broken clouds               803           240
# 2       16         Overcast clouds               804           240
# 3       16               Clear Sky               800           260
# 4       16               Clear Sky               800           290
#
#    dep_wind_gust_spd  dep_wind_spd        Date  dep_hours Origin_Airport
# 0                3.2           2.1  12/31/2019         19            MCO
# 1                3.2           1.5  12/31/2019         20            MCO
# 2                3.2           2.1  12/31/2019         21            MCO
# 3                3.2           1.5  12/31/2019         22            MCO
# 4                3.6           1.5  12/31/2019         23            MCO
# 20
#    dep_azimuth  dep_clouds  dep_dewpt  dep_elev_angle  dep_h_angle  \
# 0        253.2         100       -6.2           -16.1          NaN
# 1        262.4          96       -6.2           -27.0          NaN
# 2        272.1          50       -6.1           -38.1          NaN
# 3        283.6          43       -6.2           -49.1          NaN
# 4        299.4          25       -6.2           -59.5          NaN
#
#    dep_precip  dep_pres dep_revision_status  dep_rh  dep_snow  dep_temp  \
# 0         0.0       985               final      74       0.0      -2.2
# 1         0.0       984               final      74       0.0      -2.2
# 2         0.0       985               final      78       0.0      -2.8
# 3         0.0       984               final      78       0.0      -2.9
# 4         0.0       984               final      80       0.0      -3.3
#
#    dep_vis dep_weather.description  dep_weather.code  dep_wind_dir  \
# 0       16         Overcast clouds               804           260
# 1       16         Overcast clouds               804           260
# 2       16           Broken clouds               803           260
# 3       16           Broken clouds               803           250
# 4       16        Scattered clouds               802           245
#
#    dep_wind_gust_spd  dep_wind_spd        Date  dep_hours Origin_Airport
# 0               11.3          6.20  12/31/2019         18            ORD
# 1               11.2          6.70  12/31/2019         19            ORD
# 2               10.3          4.59  12/31/2019         20            ORD
# 3                8.0          4.72  12/31/2019         21            ORD
# 4                7.2          3.85  12/31/2019         22            ORD
# 20

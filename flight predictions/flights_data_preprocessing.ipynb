# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# This is new
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %% [markdown]
# #### Read and pre-process data

# %% [markdown]
# ### Fetching departure data

# %%
# fetch data 

main_data = pd.read_csv('flight_data\mco_syr_sw_dep_20_21_22_23.csv')
main_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number  \
# 0           F9          1/1/2020         104.00      N365FR
# 1           F9          1/1/2020         105.00      N309FR
# 2           F9          1/1/2020         106.00      N701FR
# 3           F9          1/1/2020         183.00      N238FR
# 4           F9          1/1/2020         679.00      N709FR
#
#   Destination Airport Scheduled departure time Actual departure time  \
# 0                 SJU                    23:05                 23:01
# 1                 ORD                     7:05                  6:57
# 2                 SJU                    13:49                 13:44
# 3                 OMA                    18:25                 19:01
# 4                 DEN                     6:00                  5:56
#
#    Scheduled elapsed time (Minutes)  Actual elapsed time (Minutes)  \
# 0                            170.00                         163.00
# 1                            189.00                         181.00
# 2                            170.00                         172.00
# 3                            208.00                         199.00
# 4                            259.00                         280.00
#
#    Departure delay (Minutes) Wheels-off time  Taxi-Out time (Minutes)  \
# 0                      -4.00           23:16                    15.00
# 1                      -8.00            7:10                    13.00
# 2                      -5.00           14:02                    18.00
# 3                      36.00           19:14                    13.00
# 4                      -4.00            6:22                    26.00
#
#    Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# 0                     0.00                     0.00
# 1                     0.00                     0.00
# 2                     0.00                     0.00
# 3                    27.00                     0.00
# 4                     0.00                     0.00
#
#    Delay National Aviation System (Minutes)  Delay Security (Minutes)  \
# 0                                      0.00                      0.00
# 1                                      0.00                      0.00
# 2                                      0.00                      0.00
# 3                                      0.00                      0.00
# 4                                     17.00                      0.00
#
#    Delay Late Aircraft Arrival (Minutes)
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
# 3                                   0.00
# 4                                   0.00

# %%
main_data.dtypes
# Out:
# Carrier Code                                 object
# Date (MM/DD/YYYY)                            object
# Flight Number                               float64
# Tail Number                                  object
# Destination Airport                          object
# Scheduled departure time                     object
# Actual departure time                        object
# Scheduled elapsed time (Minutes)            float64
# Actual elapsed time (Minutes)               float64
# Departure delay (Minutes)                   float64
# Wheels-off time                              object
# Taxi-Out time (Minutes)                     float64
# Delay Carrier (Minutes)                     float64
# Delay Weather (Minutes)                     float64
# Delay National Aviation System (Minutes)    float64
# Delay Security (Minutes)                    float64
# Delay Late Aircraft Arrival (Minutes)       float64
# dtype: object

# %%
len(main_data)
# Out:
# 65004

# %%
main_data.rename(columns = {'Destination Airport' : 'Destination_Airport' , 
                            'Carrier Code' : 'Carrier_Code',
                            'Flight Number' : 'Flight_Number',
                            'Tail Number' : 'Tail_Number',
                            'Date (MM/DD/YYYY)':'Date', 
                            'Delay Carrier (Minutes)' : 'dep_Delay_Carrier',
                             'Delay Weather (Minutes)' : 'dep_Delay_Weather',
                 'Delay National Aviation System (Minutes)' : 'dep_Delay_National_Aviation_System',
                 'Delay Security (Minutes)' : 'dep_Delay_Security',
                 'Delay Late Aircraft Arrival (Minutes)' : 'dep_Delay_Late_Aircraft_Arrival'},inplace = True)

# %%
main_data.dtypes
# Out:
# Carrier_Code                           object
# Date                                   object
# Flight_Number                         float64
# Tail_Number                            object
# Destination_Airport                    object
# Scheduled departure time               object
# Actual departure time                  object
# Scheduled elapsed time (Minutes)      float64
# Actual elapsed time (Minutes)         float64
# Departure delay (Minutes)             float64
# Wheels-off time                        object
# Taxi-Out time (Minutes)               float64
# dep_Delay_Carrier                     float64
# dep_Delay_Weather                     float64
# dep_Delay_National_Aviation_System    float64
# dep_Delay_Security                    float64
# dep_Delay_Late_Aircraft_Arrival       float64
# dtype: object

# %%
main_data = main_data[main_data['Destination_Airport'] == 'SYR']
len(main_data)
# Out:
# 880

# %%
main_data['dep_hour'] = main_data['Scheduled departure time'].str.split(":").str[0].astype('int64')
main_data['Date'] = pd.to_datetime( main_data['Date'],format ="%m/%d/%Y") 
main_data['dep_day'] = main_data['Date'].dt.day_of_week.astype('int64') 
main_data['dep_year'] = main_data['Date'].dt.year.astype('int64')
main_data.dtypes
# Out:
# Carrier_Code                                  object
# Date                                  datetime64[ns]
# Flight_Number                                float64
# Tail_Number                                   object
# Destination_Airport                           object
# Scheduled departure time                      object
# Actual departure time                         object
# Scheduled elapsed time (Minutes)             float64
# Actual elapsed time (Minutes)                float64
# Departure delay (Minutes)                    float64
# Wheels-off time                               object
# Taxi-Out time (Minutes)                      float64
# dep_Delay_Carrier                            float64
# dep_Delay_Weather                            float64
# dep_Delay_National_Aviation_System           float64
# dep_Delay_Security                           float64
# dep_Delay_Late_Aircraft_Arrival              float64
# dep_hour                                       int64
# dep_day                                        int64
# dep_year                                       int64
# dtype: object

# %%
main_data['dep_hour'].value_counts()
# Out:
# dep_hour
# 8     153
# 17    148
# 7     123
# 9      80
# 16     67
# 15     62
# 12     56
# 11     54
# 14     53
# 6      37
# 13     19
# 10     19
# 18      6
# 5       3
# Name: count, dtype: int64

# %%
main_data['dep_year'].value_counts()
# Out:
# dep_year
# 2023    281
# 2022    242
# 2021    213
# 2020    144
# Name: count, dtype: int64

# %%
main_data['dep_order'] = 'latter'

# %%
main_data.head()
# Out:
#     Carrier_Code       Date  Flight_Number Tail_Number Destination_Airport  \
# 35            F9 2020-01-01       1,214.00      N311FR                 SYR
# 64            F9 2021-01-01       1,214.00      N220FR                 SYR
# 102           F9 2022-01-01       1,214.00      N233FR                 SYR
# 243           F9 2021-01-02       1,214.00      N334FR                 SYR
# 348           F9 2023-01-02       1,216.00      N360FR                 SYR
#
#     Scheduled departure time Actual departure time  \
# 35                     11:55                 11:47
# 64                     14:14                 14:36
# 102                    17:01                 20:00
# 243                    14:14                 14:14
# 348                     7:55                  9:52
#
#      Scheduled elapsed time (Minutes)  Actual elapsed time (Minutes)  \
# 35                             164.00                         156.00
# 64                             170.00                         148.00
# 102                            166.00                         158.00
# 243                            170.00                         141.00
# 348                            169.00                         168.00
#
#      Departure delay (Minutes)  ... Taxi-Out time (Minutes)  \
# 35                       -8.00  ...                   14.00
# 64                       22.00  ...                   14.00
# 102                     179.00  ...                   25.00
# 243                       0.00  ...                   10.00
# 348                     117.00  ...                   17.00
#
#      dep_Delay_Carrier  dep_Delay_Weather  dep_Delay_National_Aviation_System  \
# 35                0.00               0.00                                0.00
# 64                0.00               0.00                                0.00
# 102              15.00               0.00                               13.00
# 243               0.00               0.00                                0.00
# 348              15.00               0.00                              101.00
#
#      dep_Delay_Security  dep_Delay_Late_Aircraft_Arrival  dep_hour  dep_day  \
# 35                 0.00                             0.00        11        2
# 64                 0.00                             0.00        14        4
# 102                0.00                           143.00        17        5
# 243                0.00                             0.00        14        5
# 348                0.00                             0.00         7        0
#
#      dep_year  dep_order
# 35       2020     latter
# 64       2021     latter
# 102      2022     latter
# 243      2021     latter
# 348      2023     latter
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Fetching arrival data

# %%
# fetch data 

arr_data = pd.read_csv('flight_data\mco_syr_sw_arr_20_21_22_23.csv')
arr_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           F9          1/1/2020         958.00      N227FR            RSW
# 1           F9          1/1/2020       1,214.00      N311FR            MCO
# 2           F9          1/1/2021       1,214.00      N220FR            MCO
# 3           F9          1/1/2021       2,542.00      N232FR            TPA
# 4           F9          1/1/2022         958.00         NaN            RSW
#
#   Scheduled Arrival Time Actual Arrival Time  \
# 0                  12:44               12:15
# 1                  14:39               14:23
# 2                  17:04               17:04
# 3                  12:03               11:39
# 4                   9:59                0:00
#
#    Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                            179.00                         162.00
# 1                            164.00                         156.00
# 2                            170.00                         148.00
# 3                            163.00                         157.00
# 4                            179.00                           0.00
#
#    Arrival Delay (Minutes) Wheels-on Time  Taxi-In time (Minutes)  \
# 0                   -29.00          12:11                    4.00
# 1                   -16.00          14:17                    6.00
# 2                     0.00          16:59                    5.00
# 3                   -24.00          11:33                    6.00
# 4                     0.00           0:00                    0.00
#
#    Delay Carrier (Minutes)  Delay Weather (Minutes)  \
# 0                     0.00                     0.00
# 1                     0.00                     0.00
# 2                     0.00                     0.00
# 3                     0.00                     0.00
# 4                     0.00                     0.00
#
#    Delay National Aviation System (Minutes)  Delay Security (Minutes)  \
# 0                                      0.00                      0.00
# 1                                      0.00                      0.00
# 2                                      0.00                      0.00
# 3                                      0.00                      0.00
# 4                                      0.00                      0.00
#
#    Delay Late Aircraft Arrival (Minutes)
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
# 3                                   0.00
# 4                                   0.00

# %%
arr_data.rename(columns = {'Origin Airport' : 'Origin_Airport' , 
                            'Carrier Code' : 'Carrier_Code',
                            'Flight Number' : 'Flight_Number',
                            'Tail Number' : 'Tail_Number',
                            'Date (MM/DD/YYYY)':'Date', 
                            'Delay Carrier (Minutes)' : 'arr_Delay_Carrier',
                             'Delay Weather (Minutes)' : 'arr_Delay_Weather',
                 'Delay National Aviation System (Minutes)' : 'arr_Delay_National_Aviation_System',
                 'Delay Security (Minutes)' : 'arr_Delay_Security',
                 'Delay Late Aircraft Arrival (Minutes)' : 'arr_Delay_Late_Aircraft_Arrival'},inplace = True)

# %%
arr_data.dtypes
# Out:
# Carrier_Code                           object
# Date                                   object
# Flight_Number                         float64
# Tail_Number                            object
# Origin_Airport                         object
# Scheduled Arrival Time                 object
# Actual Arrival Time                    object
# Scheduled Elapsed Time (Minutes)      float64
# Actual Elapsed Time (Minutes)         float64
# Arrival Delay (Minutes)               float64
# Wheels-on Time                         object
# Taxi-In time (Minutes)                float64
# arr_Delay_Carrier                     float64
# arr_Delay_Weather                     float64
# arr_Delay_National_Aviation_System    float64
# arr_Delay_Security                    float64
# arr_Delay_Late_Aircraft_Arrival       float64
# dtype: object

# %%
len(arr_data)
# Out:
# 1649

# %%
arr_data = arr_data[arr_data['Origin_Airport'] == 'MCO']
len(arr_data)
# Out:
# 880

# %%
arr_data['arr_hour'] = arr_data['Scheduled Arrival Time'].str.split(":").str[0].astype('int64')

arr_data['Date'] = pd.to_datetime( arr_data['Date'],format ="%m/%d/%Y") 
arr_data['arr_day'] = arr_data['Date'].dt.day_of_week.astype('int64')
arr_data['arr_year'] = arr_data['Date'].dt.year.astype('int64')
arr_data.drop(columns = ['Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)'],inplace = True)

arr_data.dtypes
# Out:
# Carrier_Code                                  object
# Date                                  datetime64[ns]
# Flight_Number                                float64
# Tail_Number                                   object
# Origin_Airport                                object
# Scheduled Arrival Time                        object
# Actual Arrival Time                           object
# Arrival Delay (Minutes)                      float64
# Wheels-on Time                                object
# Taxi-In time (Minutes)                       float64
# arr_Delay_Carrier                            float64
# arr_Delay_Weather                            float64
# arr_Delay_National_Aviation_System           float64
# arr_Delay_Security                           float64
# arr_Delay_Late_Aircraft_Arrival              float64
# arr_hour                                       int64
# arr_day                                        int64
# arr_year                                       int64
# dtype: object

# %%
arr_data['arr_hour'].value_counts()
# Out:
# arr_hour
# 19    178
# 11    152
# 10     98
# 9      73
# 17     62
# 14     58
# 12     57
# 18     56
# 15     44
# 20     35
# 8      24
# 16     23
# 13     19
# 21      1
# Name: count, dtype: int64

# %%
arr_data['arr_year'].value_counts()
# Out:
# arr_year
# 2023    281
# 2022    242
# 2021    213
# 2020    144
# Name: count, dtype: int64

# %% [markdown]
# ### Merging departure and arrival data

# %%
merged_df = pd.merge(main_data, arr_data, on=['Carrier_Code','Date', 'Flight_Number', 'Tail_Number'], how='inner')
merged_df.head()
# Out:
#   Carrier_Code       Date  Flight_Number Tail_Number Destination_Airport  \
# 0           F9 2020-01-01       1,214.00      N311FR                 SYR
# 1           F9 2021-01-01       1,214.00      N220FR                 SYR
# 2           F9 2022-01-01       1,214.00      N233FR                 SYR
# 3           F9 2021-01-02       1,214.00      N334FR                 SYR
# 4           F9 2023-01-02       1,216.00      N360FR                 SYR
#
#   Scheduled departure time Actual departure time  \
# 0                    11:55                 11:47
# 1                    14:14                 14:36
# 2                    17:01                 20:00
# 3                    14:14                 14:14
# 4                     7:55                  9:52
#
#    Scheduled elapsed time (Minutes)  Actual elapsed time (Minutes)  \
# 0                            164.00                         156.00
# 1                            170.00                         148.00
# 2                            166.00                         158.00
# 3                            170.00                         141.00
# 4                            169.00                         168.00
#
#    Departure delay (Minutes)  ... Wheels-on Time  Taxi-In time (Minutes)  \
# 0                      -8.00  ...          14:17                    6.00
# 1                      22.00  ...          16:59                    5.00
# 2                     179.00  ...          22:32                    6.00
# 3                       0.00  ...          16:30                    5.00
# 4                     117.00  ...          12:34                    6.00
#
#    arr_Delay_Carrier  arr_Delay_Weather  arr_Delay_National_Aviation_System  \
# 0               0.00               0.00                                0.00
# 1               0.00               0.00                                0.00
# 2              15.00               0.00                               13.00
# 3               0.00               0.00                                0.00
# 4              15.00               0.00                              101.00
#
#    arr_Delay_Security  arr_Delay_Late_Aircraft_Arrival  arr_hour  arr_day  \
# 0                0.00                             0.00        14        2
# 1                0.00                             0.00        17        4
# 2                0.00                           143.00        19        5
# 3                0.00                             0.00        17        5
# 4                0.00                             0.00        10        0
#
#    arr_year
# 0      2020
# 1      2021
# 2      2022
# 3      2021
# 4      2023
#
# [5 rows x 35 columns]

# %%
merged_df.dtypes
# Out:
# Carrier_Code                                  object
# Date                                  datetime64[ns]
# Flight_Number                                float64
# Tail_Number                                   object
# Destination_Airport                           object
# Scheduled departure time                      object
# Actual departure time                         object
# Scheduled elapsed time (Minutes)             float64
# Actual elapsed time (Minutes)                float64
# Departure delay (Minutes)                    float64
# Wheels-off time                               object
# Taxi-Out time (Minutes)                      float64
# dep_Delay_Carrier                            float64
# dep_Delay_Weather                            float64
# dep_Delay_National_Aviation_System           float64
# dep_Delay_Security                           float64
# dep_Delay_Late_Aircraft_Arrival              float64
# dep_hour                                       int64
# dep_day                                        int64
# dep_year                                       int64
# dep_order                                     object
# Origin_Airport                                object
# Scheduled Arrival Time                        object
# Actual Arrival Time                           object
# Arrival Delay (Minutes)                      float64
# Wheels-on Time                                object
# Taxi-In time (Minutes)                       float64
# arr_Delay_Carrier                            float64
# arr_Delay_Weather                            float64
# arr_Delay_National_Aviation_System           float64
# arr_Delay_Security                           float64
# arr_Delay_Late_Aircraft_Arrival              float64
# arr_hour                                       int64
# arr_day                                        int64
# arr_year                                       int64
# dtype: object

# %%
len(merged_df)
# Out:
# 880

# %%
merged_df.to_csv('flight_data\mco_syr_sw_20_21_22_23.csv')

# %%
new_df = pd.read_csv('flight_data\mco_syr_sw_20_21_22_23.csv')
len(new_df)
new_df.head()
# Out:
# 880
#    Unnamed: 0 Carrier_Code        Date  Flight_Number Tail_Number  \
# 0           0           F9  2020-01-01       1,214.00      N311FR
# 1           1           F9  2021-01-01       1,214.00      N220FR
# 2           2           F9  2022-01-01       1,214.00      N233FR
# 3           3           F9  2021-01-02       1,214.00      N334FR
# 4           4           F9  2023-01-02       1,216.00      N360FR
#
#   Destination_Airport Scheduled departure time Actual departure time  \
# 0                 SYR                    11:55                 11:47
# 1                 SYR                    14:14                 14:36
# 2                 SYR                    17:01                 20:00
# 3                 SYR                    14:14                 14:14
# 4                 SYR                     7:55                  9:52
#
#    Scheduled elapsed time (Minutes)  Actual elapsed time (Minutes)  ...  \
# 0                            164.00                         156.00  ...
# 1                            170.00                         148.00  ...
# 2                            166.00                         158.00  ...
# 3                            170.00                         141.00  ...
# 4                            169.00                         168.00  ...
#
#    Wheels-on Time Taxi-In time (Minutes)  arr_Delay_Carrier  \
# 0           14:17                   6.00               0.00
# 1           16:59                   5.00               0.00
# 2           22:32                   6.00              15.00
# 3           16:30                   5.00               0.00
# 4           12:34                   6.00              15.00
#
#    arr_Delay_Weather  arr_Delay_National_Aviation_System  arr_Delay_Security  \
# 0               0.00                                0.00                0.00
# 1               0.00                                0.00                0.00
# 2               0.00                               13.00                0.00
# 3               0.00                                0.00                0.00
# 4               0.00                              101.00                0.00
#
#    arr_Delay_Late_Aircraft_Arrival  arr_hour  arr_day  arr_year
# 0                             0.00        14        2      2020
# 1                             0.00        17        4      2021
# 2                           143.00        19        5      2022
# 3                             0.00        17        5      2021
# 4                             0.00        10        0      2023
#
# [5 rows x 36 columns]

# %% [markdown]
# ### combining multiple years of data

# %%
# # Read the CSV files
# df_20_21 = pd.read_csv('flight_data\ord_syr_ua_20_21.csv')
# df_22_23 = pd.read_csv('flight_data\ord_syr_ua_22_23.csv')

# # Concatenate the dataframes
# combined_df = pd.concat([df_20_21, df_22_23])

# # Reset the index
# combined_df.reset_index(drop=True, inplace=True)

# # Save the combined dataframe to a new CSV file
# combined_df.to_csv('flight_data\ord_syr_ua_20_21_22_23.csv', index=False)

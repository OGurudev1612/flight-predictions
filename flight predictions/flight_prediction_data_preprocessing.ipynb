# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# This is new
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %% [markdown]
# ### Fetching flight data

# %%
pred_data = pd.read_csv('pred_data\CIS_662 _FINAL_Predictions.csv')

# %%
pred_data.head()
# Out:
#         DATE     DAY FLIGHT NUMBER ORIGIN DEPARTURE TIME ARRIVAL TIME  \
# 0  4/19/2024  FRIDAY       UA 1400    ORD        6:52 PM      9:47 PM
# 1  4/19/2024  FRIDAY       AA 3402    ORD        7:59 PM     10:52 PM
# 2  4/19/2024  FRIDAY        B6 116    JFK        1:34 PM      2:51 PM
# 3  4/19/2024  FRIDAY       DL 5182    JFK        2:55 PM      4:21 PM
# 4  4/19/2024  FRIDAY       WN 5285    MCO       11:35 AM      2:20 PM
#
#    ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0             NaN                               NaN
# 1             NaN                               NaN
# 2             NaN                               NaN
# 3             NaN                               NaN
# 4             NaN                               NaN
#
#    ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   dep_order
# 0     early
# 1    latter
# 2     early
# 3    latter
# 4     early

# %%
pred_data.dtypes
# Out:
# DATE                                  object
# DAY                                   object
# FLIGHT NUMBER                         object
# ORIGIN                                object
# DEPARTURE TIME                        object
# ARRIVAL TIME                          object
# ARRIVAL STATUS                       float64
# ARRIVAL STATUS_Prev_flight_early     float64
# ARRIVAL STATUS_Prev_flight_ontime    float64
# ARRIVAL STATUS_Prev_flight_late      float64
# dep_order                             object
# dtype: object

# %%
pred_data['DATE'] = pd.to_datetime( pred_data['DATE'],format ="%m/%d/%Y")
pred_data['DAY'] = pred_data['DATE'].dt.day_of_week.astype('object')
pred_data['Carrier_Code'] = pred_data['FLIGHT NUMBER'].str[0:2].astype('object')
pred_data['DEPARTURE TIME'] = pd.to_datetime(pred_data['DEPARTURE TIME'], format = '%I:%M %p')
pred_data['dep_hour']= pred_data['DEPARTURE TIME'].dt.hour.astype('object')
pred_data['dep_min'] = pred_data['DEPARTURE TIME'].dt.minute.astype('object')
pred_data['ARRIVAL TIME'] = pd.to_datetime(pred_data['ARRIVAL TIME'], format = '%I:%M %p')
pred_data['arr_hour']= pred_data['ARRIVAL TIME'].dt.hour.astype('object')
pred_data['arr_min'] = pred_data['ARRIVAL TIME'].dt.minute.astype('object')
pred_data.rename(columns = {'ORIGIN' : 'Origin_Airport'},inplace =True)
pred_data.head()
# Out:
#         DATE DAY FLIGHT NUMBER Origin_Airport      DEPARTURE TIME  \
# 0 2024-04-19   4       UA 1400            ORD 1900-01-01 18:52:00
# 1 2024-04-19   4       AA 3402            ORD 1900-01-01 19:59:00
# 2 2024-04-19   4        B6 116            JFK 1900-01-01 13:34:00
# 3 2024-04-19   4       DL 5182            JFK 1900-01-01 14:55:00
# 4 2024-04-19   4       WN 5285            MCO 1900-01-01 11:35:00
#
#          ARRIVAL TIME  ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0 1900-01-01 21:47:00             NaN                               NaN
# 1 1900-01-01 22:52:00             NaN                               NaN
# 2 1900-01-01 14:51:00             NaN                               NaN
# 3 1900-01-01 16:21:00             NaN                               NaN
# 4 1900-01-01 14:20:00             NaN                               NaN
#
#    ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   dep_order Carrier_Code dep_hour dep_min arr_hour arr_min
# 0     early           UA       18      52       21      47
# 1    latter           AA       19      59       22      52
# 2     early           B6       13      34       14      51
# 3    latter           DL       14      55       16      21
# 4     early           WN       11      35       14      20

# %%
pred_data.dtypes
# Out:
# DATE                                 datetime64[ns]
# DAY                                          object
# FLIGHT NUMBER                                object
# Origin_Airport                               object
# DEPARTURE TIME                       datetime64[ns]
# ARRIVAL TIME                         datetime64[ns]
# ARRIVAL STATUS                              float64
# ARRIVAL STATUS_Prev_flight_early            float64
# ARRIVAL STATUS_Prev_flight_ontime           float64
# ARRIVAL STATUS_Prev_flight_late             float64
# dep_order                                    object
# Carrier_Code                                 object
# dep_hour                                     object
# dep_min                                      object
# arr_hour                                     object
# arr_min                                      object
# dtype: object

# %%
pred_data.head(30)
# Out:
#          DATE DAY FLIGHT NUMBER Origin_Airport      DEPARTURE TIME  \
# 0  2024-04-19   4       UA 1400            ORD 1900-01-01 18:52:00
# 1  2024-04-19   4       AA 3402            ORD 1900-01-01 19:59:00
# 2  2024-04-19   4        B6 116            JFK 1900-01-01 13:34:00
# 3  2024-04-19   4       DL 5182            JFK 1900-01-01 14:55:00
# 4  2024-04-19   4       WN 5285            MCO 1900-01-01 11:35:00
# 5  2024-04-19   4        B6 656            MCO 1900-01-01 13:35:00
# 6  2024-04-20   5       UA 1400            ORD 1900-01-01 18:52:00
# 7  2024-04-20   5       AA 3402            ORD 1900-01-01 19:59:00
# 8  2024-04-20   5        B6 116            JFK 1900-01-01 13:25:00
# 9  2024-04-20   5       DL 5182            JFK 1900-01-01 14:55:00
# 10 2024-04-20   5        B6 656            MCO 1900-01-01 13:35:00
# 11 2024-04-21   6       UA 1400            ORD 1900-01-01 18:52:00
# 12 2024-04-21   6       AA 3402            ORD 1900-01-01 19:59:00
# 13 2024-04-21   6        B6 116            JFK 1900-01-01 13:35:00
# 14 2024-04-21   6       DL 5182            JFK 1900-01-01 14:55:00
# 15 2024-04-21   6       WN 5285            MCO 1900-01-01 11:05:00
# 16 2024-04-21   6        B6 656            MCO 1900-01-01 13:35:00
# 17 2024-04-22   0       UA 1400            ORD 1900-01-01 18:52:00
# 18 2024-04-22   0       AA 3402            ORD 1900-01-01 19:59:00
# 19 2024-04-22   0        B6 116            JFK 1900-01-01 13:35:00
# 20 2024-04-22   0       DL 5182            JFK 1900-01-01 14:55:00
# 21 2024-04-22   0       WN 5285            MCO 1900-01-01 11:35:00
# 22 2024-04-22   0        B6 656            MCO 1900-01-01 13:34:00
#
#           ARRIVAL TIME  ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0  1900-01-01 21:47:00             NaN                               NaN
# 1  1900-01-01 22:52:00             NaN                               NaN
# 2  1900-01-01 14:51:00             NaN                               NaN
# 3  1900-01-01 16:21:00             NaN                               NaN
# 4  1900-01-01 14:20:00             NaN                               NaN
# 5  1900-01-01 16:25:00             NaN                               NaN
# 6  1900-01-01 21:47:00             NaN                               NaN
# 7  1900-01-01 22:52:00             NaN                               NaN
# 8  1900-01-01 14:41:00             NaN                               NaN
# 9  1900-01-01 16:21:00             NaN                               NaN
# 10 1900-01-01 16:25:00             NaN                               NaN
# 11 1900-01-01 21:47:00             NaN                               NaN
# 12 1900-01-01 22:52:00             NaN                               NaN
# 13 1900-01-01 14:51:00             NaN                               NaN
# 14 1900-01-01 16:21:00             NaN                               NaN
# 15 1900-01-01 13:50:00             NaN                               NaN
# 16 1900-01-01 16:25:00             NaN                               NaN
# 17 1900-01-01 21:47:00             NaN                               NaN
# 18 1900-01-01 22:52:00             NaN                               NaN
# 19 1900-01-01 14:51:00             NaN                               NaN
# 20 1900-01-01 16:21:00             NaN                               NaN
# 21 1900-01-01 14:20:00             NaN                               NaN
# 22 1900-01-01 16:25:00             NaN                               NaN
#
#     ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# 5                                 NaN                              NaN
# 6                                 NaN                              NaN
# 7                                 NaN                              NaN
# 8                                 NaN                              NaN
# 9                                 NaN                              NaN
# 10                                NaN                              NaN
# 11                                NaN                              NaN
# 12                                NaN                              NaN
# 13                                NaN                              NaN
# 14                                NaN                              NaN
# 15                                NaN                              NaN
# 16                                NaN                              NaN
# 17                                NaN                              NaN
# 18                                NaN                              NaN
# 19                                NaN                              NaN
# 20                                NaN                              NaN
# 21                                NaN                              NaN
# 22                                NaN                              NaN
#
#    dep_order Carrier_Code dep_hour dep_min arr_hour arr_min
# 0      early           UA       18      52       21      47
# 1     latter           AA       19      59       22      52
# 2      early           B6       13      34       14      51
# 3     latter           DL       14      55       16      21
# 4      early           WN       11      35       14      20
# 5     latter           B6       13      35       16      25
# 6      early           UA       18      52       21      47
# 7     latter           AA       19      59       22      52
# 8      early           B6       13      25       14      41
# 9     latter           DL       14      55       16      21
# 10     early           B6       13      35       16      25
# 11     early           UA       18      52       21      47
# 12    latter           AA       19      59       22      52
# 13     early           B6       13      35       14      51
# 14    latter           DL       14      55       16      21
# 15     early           WN       11       5       13      50
# 16    latter           B6       13      35       16      25
# 17     early           UA       18      52       21      47
# 18    latter           AA       19      59       22      52
# 19     early           B6       13      35       14      51
# 20    latter           DL       14      55       16      21
# 21     early           WN       11      35       14      20
# 22    latter           B6       13      34       16      25

# %%
pred_data['dep_minutes'] = 0
pred_data['dep_minutes'] = pred_data['dep_minutes'].astype('object')
pred_data['dep_hours'] = pred_data['dep_hour'].astype('object')
pred_data['arr_minutes'] = 0
pred_data['arr_minutes'] = pred_data['arr_minutes'].astype('object')
pred_data['arr_hours'] = pred_data['arr_hour'].astype('object')
pred_data.rename(columns ={'DATE':'Date'},inplace=True)
pred_data.head()
# Out:
#         Date DAY FLIGHT NUMBER Origin_Airport      DEPARTURE TIME  \
# 0 2024-04-19   4       UA 1400            ORD 1900-01-01 18:52:00
# 1 2024-04-19   4       AA 3402            ORD 1900-01-01 19:59:00
# 2 2024-04-19   4        B6 116            JFK 1900-01-01 13:34:00
# 3 2024-04-19   4       DL 5182            JFK 1900-01-01 14:55:00
# 4 2024-04-19   4       WN 5285            MCO 1900-01-01 11:35:00
#
#          ARRIVAL TIME  ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0 1900-01-01 21:47:00             NaN                               NaN
# 1 1900-01-01 22:52:00             NaN                               NaN
# 2 1900-01-01 14:51:00             NaN                               NaN
# 3 1900-01-01 16:21:00             NaN                               NaN
# 4 1900-01-01 14:20:00             NaN                               NaN
#
#    ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   dep_order Carrier_Code dep_hour dep_min arr_hour arr_min dep_minutes  \
# 0     early           UA       18      52       21      47           0
# 1    latter           AA       19      59       22      52           0
# 2     early           B6       13      34       14      51           0
# 3    latter           DL       14      55       16      21           0
# 4     early           WN       11      35       14      20           0
#
#   dep_hours arr_minutes arr_hours
# 0        18           0        21
# 1        19           0        22
# 2        13           0        14
# 3        14           0        16
# 4        11           0        14

# %%
pred_data['Date'] = pred_data['Date'].dt.strftime('%m/%d/%Y')
pred_data.dtypes
len(pred_data)
pred_data.head(30)
# Out:
# Date                                         object
# DAY                                          object
# FLIGHT NUMBER                                object
# Origin_Airport                               object
# DEPARTURE TIME                       datetime64[ns]
# ARRIVAL TIME                         datetime64[ns]
# ARRIVAL STATUS                              float64
# ARRIVAL STATUS_Prev_flight_early            float64
# ARRIVAL STATUS_Prev_flight_ontime           float64
# ARRIVAL STATUS_Prev_flight_late             float64
# dep_order                                    object
# Carrier_Code                                 object
# dep_hour                                     object
# dep_min                                      object
# arr_hour                                     object
# arr_min                                      object
# dep_minutes                                  object
# dep_hours                                    object
# arr_minutes                                  object
# arr_hours                                    object
# dtype: object
# 23
#           Date DAY FLIGHT NUMBER Origin_Airport      DEPARTURE TIME  \
# 0   04/19/2024   4       UA 1400            ORD 1900-01-01 18:52:00
# 1   04/19/2024   4       AA 3402            ORD 1900-01-01 19:59:00
# 2   04/19/2024   4        B6 116            JFK 1900-01-01 13:34:00
# 3   04/19/2024   4       DL 5182            JFK 1900-01-01 14:55:00
# 4   04/19/2024   4       WN 5285            MCO 1900-01-01 11:35:00
# 5   04/19/2024   4        B6 656            MCO 1900-01-01 13:35:00
# 6   04/20/2024   5       UA 1400            ORD 1900-01-01 18:52:00
# 7   04/20/2024   5       AA 3402            ORD 1900-01-01 19:59:00
# 8   04/20/2024   5        B6 116            JFK 1900-01-01 13:25:00
# 9   04/20/2024   5       DL 5182            JFK 1900-01-01 14:55:00
# 10  04/20/2024   5        B6 656            MCO 1900-01-01 13:35:00
# 11  04/21/2024   6       UA 1400            ORD 1900-01-01 18:52:00
# 12  04/21/2024   6       AA 3402            ORD 1900-01-01 19:59:00
# 13  04/21/2024   6        B6 116            JFK 1900-01-01 13:35:00
# 14  04/21/2024   6       DL 5182            JFK 1900-01-01 14:55:00
# 15  04/21/2024   6       WN 5285            MCO 1900-01-01 11:05:00
# 16  04/21/2024   6        B6 656            MCO 1900-01-01 13:35:00
# 17  04/22/2024   0       UA 1400            ORD 1900-01-01 18:52:00
# 18  04/22/2024   0       AA 3402            ORD 1900-01-01 19:59:00
# 19  04/22/2024   0        B6 116            JFK 1900-01-01 13:35:00
# 20  04/22/2024   0       DL 5182            JFK 1900-01-01 14:55:00
# 21  04/22/2024   0       WN 5285            MCO 1900-01-01 11:35:00
# 22  04/22/2024   0        B6 656            MCO 1900-01-01 13:34:00
#
#           ARRIVAL TIME  ARRIVAL STATUS  ARRIVAL STATUS_Prev_flight_early  \
# 0  1900-01-01 21:47:00             NaN                               NaN
# 1  1900-01-01 22:52:00             NaN                               NaN
# 2  1900-01-01 14:51:00             NaN                               NaN
# 3  1900-01-01 16:21:00             NaN                               NaN
# 4  1900-01-01 14:20:00             NaN                               NaN
# 5  1900-01-01 16:25:00             NaN                               NaN
# 6  1900-01-01 21:47:00             NaN                               NaN
# 7  1900-01-01 22:52:00             NaN                               NaN
# 8  1900-01-01 14:41:00             NaN                               NaN
# 9  1900-01-01 16:21:00             NaN                               NaN
# 10 1900-01-01 16:25:00             NaN                               NaN
# 11 1900-01-01 21:47:00             NaN                               NaN
# 12 1900-01-01 22:52:00             NaN                               NaN
# 13 1900-01-01 14:51:00             NaN                               NaN
# 14 1900-01-01 16:21:00             NaN                               NaN
# 15 1900-01-01 13:50:00             NaN                               NaN
# 16 1900-01-01 16:25:00             NaN                               NaN
# 17 1900-01-01 21:47:00             NaN                               NaN
# 18 1900-01-01 22:52:00             NaN                               NaN
# 19 1900-01-01 14:51:00             NaN                               NaN
# 20 1900-01-01 16:21:00             NaN                               NaN
# 21 1900-01-01 14:20:00             NaN                               NaN
# 22 1900-01-01 16:25:00             NaN                               NaN
#
#     ARRIVAL STATUS_Prev_flight_ontime  ARRIVAL STATUS_Prev_flight_late  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# 5                                 NaN                              NaN
# 6                                 NaN                              NaN
# 7                                 NaN                              NaN
# 8                                 NaN                              NaN
# 9                                 NaN                              NaN
# 10                                NaN                              NaN
# 11                                NaN                              NaN
# 12                                NaN                              NaN
# 13                                NaN                              NaN
# 14                                NaN                              NaN
# 15                                NaN                              NaN
# 16                                NaN                              NaN
# 17                                NaN                              NaN
# 18                                NaN                              NaN
# 19                                NaN                              NaN
# 20                                NaN                              NaN
# 21                                NaN                              NaN
# 22                                NaN                              NaN
#
#    dep_order Carrier_Code dep_hour dep_min arr_hour arr_min dep_minutes  \
# 0      early           UA       18      52       21      47           0
# 1     latter           AA       19      59       22      52           0
# 2      early           B6       13      34       14      51           0
# 3     latter           DL       14      55       16      21           0
# 4      early           WN       11      35       14      20           0
# 5     latter           B6       13      35       16      25           0
# 6      early           UA       18      52       21      47           0
# 7     latter           AA       19      59       22      52           0
# 8      early           B6       13      25       14      41           0
# 9     latter           DL       14      55       16      21           0
# 10     early           B6       13      35       16      25           0
# 11     early           UA       18      52       21      47           0
# 12    latter           AA       19      59       22      52           0
# 13     early           B6       13      35       14      51           0
# 14    latter           DL       14      55       16      21           0
# 15     early           WN       11       5       13      50           0
# 16    latter           B6       13      35       16      25           0
# 17     early           UA       18      52       21      47           0
# 18    latter           AA       19      59       22      52           0
# 19     early           B6       13      35       14      51           0
# 20    latter           DL       14      55       16      21           0
# 21     early           WN       11      35       14      20           0
# 22    latter           B6       13      34       16      25           0
#
#    dep_hours arr_minutes arr_hours
# 0         18           0        21
# 1         19           0        22
# 2         13           0        14
# 3         14           0        16
# 4         11           0        14
# 5         13           0        16
# 6         18           0        21
# 7         19           0        22
# 8         13           0        14
# 9         14           0        16
# 10        13           0        16
# 11        18           0        21
# 12        19           0        22
# 13        13           0        14
# 14        14           0        16
# 15        11           0        13
# 16        13           0        16
# 17        18           0        21
# 18        19           0        22
# 19        13           0        14
# 20        14           0        16
# 21        11           0        14
# 22        13           0        16

# %% [markdown]
# ### Fetching weather data and merging with flight data

# %%
# Read and process weather data files for each airport
jfk_weather_data = pd.read_csv('weather_data/JFK_weather_data_forecast_processed.csv')
syr_weather_data = pd.read_csv('weather_data/SYR_weather_data_forecast_processed.csv')
ord_weather_data = pd.read_csv('weather_data/ORD_weather_data_forecast_processed.csv')
mco_weather_data = pd.read_csv('weather_data/MCO_weather_data_forecast_processed.csv')

# Combine weather data for all airports
weather_dfs = [jfk_weather_data, ord_weather_data, mco_weather_data]
weather_data = pd.concat(weather_dfs, axis=0)
#weather_data['dep_minutes'] = weather_data['dep_minutes'].astype('object')
weather_data['dep_hours'] = weather_data['dep_hours'].astype('object')
#syr_weather_data['arr_minutes'] = syr_weather_data['arr_minutes'].astype('object')
syr_weather_data['arr_hours'] = syr_weather_data['arr_hours'].astype('object')
weather_data.head(50)
len(weather_data)
len(syr_weather_data)

# Define merging logic based on airport code
pred_data = pd.merge(pred_data, syr_weather_data, how='left', on=['Date', 'arr_hours'])
len(pred_data)
pred_data.to_csv("first.csv")

pred_data = pd.merge(pred_data, weather_data, how='left', on=['Origin_Airport', 'Date', 'dep_hours'])
pred_data.to_csv("sec.csv")
len(pred_data)


#weather_data.head()
# Out:
#     dep_clouds  dep_clouds_hi  dep_clouds_low  dep_clouds_mid  dep_dewpt  \
# 0           92              0             100               0       4.30
# 1           95              0             100               0       4.50
# 2           95              0             100               0       3.40
# 3           83             48             100               0       3.80
# 4           76             87              99               0       3.80
# 5           80            100             100               0       3.30
# 6           73            100              98               0       3.70
# 7           67             54              34              10       3.60
# 8           61             35              12             100       3.80
# 9           57              1               5              73       3.60
# 10          71             16              14               0       3.60
# 11          73            100              18               0       3.30
# 12          63              0              17               0       3.40
# 13          64              0              27               0       3.60
# 14          65              0              52               0       3.60
# 15          80             82             100               0       3.50
# 16          61            100              48               0       3.70
# 17          64            100              30               0       3.70
# 18          76            100              23              22       4.20
# 19          82             98              11              10       4.10
# 20          85            100              11             100       4.50
# 21          83             94              17             100       5.00
# 22          83              0               7             100       5.10
# 23          90              0               9              58       5.30
# 24          79              0              13              14       5.50
# 25          65              0              34              82       5.90
# 26          88              0              77              15       5.90
# 27          93            100              94               0       6.80
# 28          91            100             100               3       7.00
# 29          96            100             100              52       7.20
# 30          95            100             100             100       7.20
# 31          95            100             100             100       7.70
# 32          97            100             100             100       8.00
# 33          96            100             100              95       8.50
# 34          97            100             100             100       8.90
# 35          94             84             100             100       8.50
# 36          91             80             100             100       8.30
# 37          89            100             100             100       8.30
# 38          86             73             100             100       8.00
# 39          80             83             100             100       7.30
# 40          75             66             100              91       6.20
# 41          69             25              58             100       5.10
# 42          68             22             100               2       4.50
# 43          66             27              40               0       4.30
# 44          65             16              35               0       3.60
# 45          65              2              25              31       3.60
# 46          64            100              91              67       3.30
# 47          64              6              76               0       3.30
# 48          50              0              55               0       2.70
# 49          36              0               9               0       2.40
#
#     dep_ozone  dep_pop  dep_precip  dep_pres  dep_rh  ...  \
# 0      382.50        0        0.00  1,019.50      74  ...
# 1      375.80        0        0.00  1,020.50      77  ...
# 2      369.50        0        0.00  1,021.00      72  ...
# 3      365.30        0        0.00  1,020.50      75  ...
# 4      362.50        0        0.00  1,020.50      74  ...
# 5      354.80        0        0.00  1,021.00      72  ...
# 6      354.80        0        0.00  1,020.00      74  ...
# 7      351.50        0        0.00  1,020.00      75  ...
# 8      347.50        0        0.00  1,020.50      76  ...
# 9      346.00        0        0.00  1,020.00      76  ...
# 10     344.80        0        0.00  1,020.00      77  ...
# 11     343.00        0        0.00  1,021.50      76  ...
# 12     343.00        0        0.00  1,022.00      76  ...
# 13     341.50        0        0.00  1,022.00      75  ...
# 14     342.00        0        0.00  1,021.00      70  ...
# 15     338.30        0        0.00  1,021.50      65  ...
# 16     335.80        0        0.00  1,021.00      62  ...
# 17     334.50        0        0.00  1,021.00      58  ...
# 18     336.30        0        0.00  1,020.50      58  ...
# 19     336.80        0        0.00  1,019.50      58  ...
# 20     338.30        0        0.00  1,019.00      59  ...
# 21     342.30        0        0.00  1,019.50      62  ...
# 22     342.30        0        0.00  1,020.00      63  ...
# 23     342.00        0        0.00  1,019.50      67  ...
# 24     342.00        0        0.00  1,018.50      70  ...
# 25     341.50        0        0.00  1,018.00      76  ...
# 26     340.50        0        0.00  1,018.00      77  ...
# 27     338.30        0        0.00  1,017.50      81  ...
# 28     337.30        0        0.00  1,017.50      82  ...
# 29     340.80       25        0.25  1,018.00      82  ...
# 30     343.80       40        0.50  1,017.50      83  ...
# 31     345.30       25        0.25  1,016.50      85  ...
# 32     343.50       40        0.50  1,015.50      87  ...
# 33     347.00       25        0.25  1,015.00      88  ...
# 34     350.00       25        0.25  1,014.50      89  ...
# 35     347.80        0        0.00  1,014.50      89  ...
# 36     349.00        0        0.00  1,014.50      85  ...
# 37     352.00        0        0.00  1,015.50      82  ...
# 38     356.30        0        0.00  1,015.00      78  ...
# 39     361.00        0        0.00  1,015.50      70  ...
# 40     364.80        0        0.00  1,014.50      61  ...
# 41     370.00        0        0.00  1,014.50      53  ...
# 42     374.80        0        0.00  1,015.00      49  ...
# 43     374.50        0        0.00  1,014.50      46  ...
# 44     375.80        0        0.00  1,014.00      42  ...
# 45     378.50        0        0.00  1,009.00      42  ...
# 46     381.80        0        0.00  1,008.50      41  ...
# 47     386.50        0        0.00  1,009.00      41  ...
# 48     387.00        0        0.00  1,009.50      42  ...
# 49     391.30        0        0.00  1,010.50      44  ...
#
#     dep_weather.description  dep_weather.code  dep_wind_cdir  \
# 0           Overcast clouds               804             NE
# 1           Overcast clouds               804             NE
# 2           Overcast clouds               804             NE
# 3           Overcast clouds               804             NE
# 4           Overcast clouds               804            ENE
# 5           Overcast clouds               804            ENE
# 6           Overcast clouds               804            ENE
# 7             Broken clouds               803            ENE
# 8             Broken clouds               803            ENE
# 9             Broken clouds               803            ENE
# 10          Overcast clouds               804            ENE
# 11          Overcast clouds               804            ENE
# 12            Broken clouds               803            ENE
# 13            Broken clouds               803            ENE
# 14            Broken clouds               803            ENE
# 15          Overcast clouds               804              E
# 16            Broken clouds               803              E
# 17            Broken clouds               803              E
# 18          Overcast clouds               804              E
# 19          Overcast clouds               804            ESE
# 20          Overcast clouds               804            ESE
# 21          Overcast clouds               804            ESE
# 22          Overcast clouds               804             SE
# 23          Overcast clouds               804             SE
# 24          Overcast clouds               804             SE
# 25            Broken clouds               803             SE
# 26          Overcast clouds               804             SE
# 27          Overcast clouds               804             SE
# 28          Overcast clouds               804            SSE
# 29          Overcast clouds               804            SSE
# 30          Overcast clouds               804            SSE
# 31          Overcast clouds               804            SSE
# 32          Overcast clouds               804              S
# 33          Overcast clouds               804              S
# 34          Overcast clouds               804            SSW
# 35          Overcast clouds               804            WSW
# 36          Overcast clouds               804              W
# 37          Overcast clouds               804              W
# 38          Overcast clouds               804            WNW
# 39          Overcast clouds               804            WNW
# 40          Overcast clouds               804             NW
# 41            Broken clouds               803             NW
# 42            Broken clouds               803            WNW
# 43            Broken clouds               803            WNW
# 44            Broken clouds               803              W
# 45            Broken clouds               803              W
# 46            Broken clouds               803              W
# 47            Broken clouds               803              W
# 48            Broken clouds               803              W
# 49         Scattered clouds               802              W
#
#     dep_wind_cdir_full dep_wind_dir  dep_wind_gust_spd dep_wind_spd  \
# 0            northeast           50               9.10         6.00
# 1            northeast           50               7.70         5.20
# 2            northeast           50               7.60         5.20
# 3            northeast           50               7.60         5.20
# 4       east-northeast           60               6.80         4.80
# 5       east-northeast           60               6.80         4.40
# 6       east-northeast           60               6.40         4.40
# 7       east-northeast           60               6.00         4.00
# 8       east-northeast           60               6.00         4.00
# 9       east-northeast           60               6.00         4.00
# 10      east-northeast           60               5.60         3.60
# 11      east-northeast           60               6.00         4.00
# 12      east-northeast           60               5.60         3.60
# 13      east-northeast           60               5.20         3.60
# 14      east-northeast           70               5.60         3.60
# 15                east           80               5.60         4.00
# 16                east           90               6.00         4.00
# 17                east          100               6.40         4.80
# 18                east          100               6.80         4.80
# 19      east-southeast          110               7.20         5.20
# 20      east-southeast          120               7.30         5.60
# 21      east-southeast          120               7.20         5.60
# 22           southeast          130               6.80         5.20
# 23           southeast          130               6.60         5.20
# 24           southeast          130               6.20         4.40
# 25           southeast          130               6.50         4.40
# 26           southeast          140               6.30         4.40
# 27           southeast          140               5.90         4.00
# 28     south-southeast          150               5.30         3.60
# 29     south-southeast          150               5.20         3.60
# 30     south-southeast          160               5.20         3.20
# 31     south-southeast          160               4.40         2.80
# 32               south          170               4.00         2.80
# 33               south          190               4.00         2.80
# 34     south-southwest          210               3.60         2.40
# 35      west-southwest          240               4.00         2.80
# 36                west          260               4.40         3.06
# 37                west          280               4.80         3.33
# 38      west-northwest          300               5.20         3.60
# 39      west-northwest          303               5.20         3.60
# 40           northwest          306               5.20         3.60
# 41           northwest          310               5.20         3.60
# 42      west-northwest          296               5.46         3.86
# 43      west-northwest          283               5.73         4.13
# 44                west          270               6.00         4.40
# 45                west          266               7.20         5.06
# 46                west          263               8.40         5.73
# 47                west          260               9.60         6.40
# 48                west          270               9.60         6.40
# 49                west          280               9.60         6.40
#
#           Date  dep_hours  Origin_Airport
# 0   04/18/2024         18             JFK
# 1   04/18/2024         19             JFK
# 2   04/18/2024         20             JFK
# 3   04/18/2024         21             JFK
# 4   04/18/2024         22             JFK
# 5   04/18/2024         23             JFK
# 6   04/19/2024          0             JFK
# 7   04/19/2024          1             JFK
# 8   04/19/2024          2             JFK
# 9   04/19/2024          3             JFK
# 10  04/19/2024          4             JFK
# 11  04/19/2024          5             JFK
# 12  04/19/2024          6             JFK
# 13  04/19/2024          7             JFK
# 14  04/19/2024          8             JFK
# 15  04/19/2024          9             JFK
# 16  04/19/2024         10             JFK
# 17  04/19/2024         11             JFK
# 18  04/19/2024         12             JFK
# 19  04/19/2024         13             JFK
# 20  04/19/2024         14             JFK
# 21  04/19/2024         15             JFK
# 22  04/19/2024         16             JFK
# 23  04/19/2024         17             JFK
# 24  04/19/2024         18             JFK
# 25  04/19/2024         19             JFK
# 26  04/19/2024         20             JFK
# 27  04/19/2024         21             JFK
# 28  04/19/2024         22             JFK
# 29  04/19/2024         23             JFK
# 30  04/20/2024          0             JFK
# 31  04/20/2024          1             JFK
# 32  04/20/2024          2             JFK
# 33  04/20/2024          3             JFK
# 34  04/20/2024          4             JFK
# 35  04/20/2024          5             JFK
# 36  04/20/2024          6             JFK
# 37  04/20/2024          7             JFK
# 38  04/20/2024          8             JFK
# 39  04/20/2024          9             JFK
# 40  04/20/2024         10             JFK
# 41  04/20/2024         11             JFK
# 42  04/20/2024         12             JFK
# 43  04/20/2024         13             JFK
# 44  04/20/2024         14             JFK
# 45  04/20/2024         15             JFK
# 46  04/20/2024         16             JFK
# 47  04/20/2024         17             JFK
# 48  04/20/2024         18             JFK
# 49  04/20/2024         19             JFK
#
# [50 rows x 24 columns]
# 504
# 168
# 23
# 23

# %%
pred_data.to_csv('pred_mid.csv')

# %%
pred_data['arr_day'] = pred_data['DAY']
pred_data['dep_day'] = pred_data['DAY']
pred_data.drop(columns = ['DAY','DEPARTURE TIME','ARRIVAL TIME','ARRIVAL STATUS_Prev_flight_early',
                         'ARRIVAL STATUS_Prev_flight_ontime','ARRIVAL STATUS_Prev_flight_late',
                         'FLIGHT NUMBER','Date','ARRIVAL STATUS'],inplace = True)

# %%
pred_data.dtypes
# Out:
# Origin_Airport              object
# dep_order                   object
# Carrier_Code                object
# dep_hour                    object
# dep_min                     object
# arr_hour                    object
# arr_min                     object
# dep_minutes                 object
# dep_hours                   object
# arr_minutes                 object
# arr_hours                   object
# arr_clouds                   int64
# arr_clouds_hi                int64
# arr_clouds_low               int64
# arr_clouds_mid               int64
# arr_dewpt                  float64
# arr_ozone                  float64
# arr_pop                      int64
# arr_precip                 float64
# arr_pres                   float64
# arr_rh                       int64
# arr_snow                     int64
# arr_snow_depth               int64
# arr_temp                   float64
# arr_vis                    float64
# arr_weather.description     object
# arr_weather.code             int64
# arr_wind_cdir               object
# arr_wind_cdir_full          object
# arr_wind_dir                 int64
# arr_wind_gust_spd          float64
# arr_wind_spd               float64
# dep_clouds                   int64
# dep_clouds_hi                int64
# dep_clouds_low               int64
# dep_clouds_mid               int64
# dep_dewpt                  float64
# dep_ozone                  float64
# dep_pop                      int64
# dep_precip                 float64
# dep_pres                   float64
# dep_rh                       int64
# dep_snow                     int64
# dep_snow_depth               int64
# dep_temp                   float64
# dep_vis                    float64
# dep_weather.description     object
# dep_weather.code             int64
# dep_wind_cdir               object
# dep_wind_cdir_full          object
# dep_wind_dir                 int64
# dep_wind_gust_spd          float64
# dep_wind_spd               float64
# arr_day                     object
# dep_day                     object
# dtype: object

# %%
pred_data['dep_hour'] = pd.Categorical(pred_data['dep_hour'], categories=[i for i in range(24)])
pred_data['dep_day'] = pd.Categorical(pred_data['dep_day'], categories=[i for i in range(7)])
pred_data['dep_min'] = pd.Categorical(pred_data['dep_min'], categories=[i for i in range(60)])
pred_data['arr_hour'] = pd.Categorical(pred_data['arr_hour'], categories=[i for i in range(24)])
pred_data['arr_day'] = pd.Categorical(pred_data['arr_day'], categories=[i for i in range(7)])
pred_data['arr_min'] = pd.Categorical(pred_data['arr_min'], categories=[i for i in range(60)])
pred_data['Carrier_Code'] = pd.Categorical(pred_data['Carrier_Code'], categories=['AA', 'UA', 'DL', 'B6', 'WN'])
pred_data['Origin_Airport'] = pd.Categorical(pred_data['Origin_Airport'], categories=['ORD', 'JFK', 'MCO'])
pred_data=pred_data[['dep_hour', 'dep_day', 'Origin_Airport', 'arr_hour', 'arr_day',
       'dep_min', 'arr_min', 'arr_clouds', 'arr_dewpt',
       'arr_precip', 'arr_pres', 'arr_rh', 'arr_snow', 'arr_temp', 'arr_vis',
       'arr_weather.code', 'arr_wind_dir', 'arr_wind_gust_spd', 'arr_wind_spd',
       'dep_clouds', 'dep_dewpt', 'dep_precip', 'dep_pres', 'dep_rh',
       'dep_snow', 'dep_temp', 'dep_vis', 'dep_weather.code', 'dep_wind_dir',
       'dep_wind_gust_spd', 'dep_wind_spd','dep_order']]
pred_data.head()
pred_data.columns
# Out:
#   dep_hour dep_day Origin_Airport arr_hour arr_day dep_min arr_min  \
# 0       18       4            ORD       21       4      52      47
# 1       19       4            ORD       22       4      59      52
# 2       13       4            JFK       14       4      34      51
# 3       14       4            JFK       16       4      55      21
# 4       11       4            MCO       14       4      35      20
#
#    arr_clouds  arr_dewpt  arr_precip  ...  dep_pres  dep_rh  dep_snow  \
# 0          69       8.00        0.50  ...    996.50      35         0
# 1          66       7.20        0.25  ...    996.50      37         0
# 2          84       7.20        0.50  ...  1,019.50      58         0
# 3          86       7.90        0.76  ...  1,019.00      59         0
# 4          84       7.20        0.50  ...  1,015.00      58         0
#
#    dep_temp  dep_vis  dep_weather.code  dep_wind_dir  dep_wind_gust_spd  \
# 0     12.70    24.00               801           280              12.50
# 1     12.10    24.00               803           280              11.10
# 2     12.10    24.00               804           110               7.20
# 3     12.30    24.00               804           120               7.30
# 4     28.10    24.00               801           280               2.40
#
#    dep_wind_spd  dep_order
# 0          8.40      early
# 1          7.60     latter
# 2          5.20      early
# 3          5.60     latter
# 4          2.00      early
#
# [5 rows x 32 columns]
# Index(['dep_hour', 'dep_day', 'Origin_Airport', 'arr_hour', 'arr_day',
#        'dep_min', 'arr_min', 'arr_clouds', 'arr_dewpt', 'arr_precip',
#        'arr_pres', 'arr_rh', 'arr_snow', 'arr_temp', 'arr_vis',
#        'arr_weather.code', 'arr_wind_dir', 'arr_wind_gust_spd', 'arr_wind_spd',
#        'dep_clouds', 'dep_dewpt', 'dep_precip', 'dep_pres', 'dep_rh',
#        'dep_snow', 'dep_temp', 'dep_vis', 'dep_weather.code', 'dep_wind_dir',
#        'dep_wind_gust_spd', 'dep_wind_spd', 'dep_order'],
#       dtype='object')

# %% [markdown]
# ### Spliting data into latter and early flights

# %%
pred_data1 = pred_data[pred_data['dep_order'] == 'early']
pred_data2 = pred_data[pred_data['dep_order'] == 'latter']

# %%
pred_data1.drop(columns=['dep_order'],inplace = True)
pred_data2.drop(columns=['dep_order'],inplace = True)
# Out:
# C:\Users\gurud\AppData\Local\Temp\ipykernel_27312\2195326561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_data1.drop(columns=['dep_order'],inplace = True)
# C:\Users\gurud\AppData\Local\Temp\ipykernel_27312\2195326561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_data2.drop(columns=['dep_order'],inplace = True)

# %%
pred_data1.head(22)
# Out:
#    dep_hour dep_day Origin_Airport arr_hour arr_day dep_min arr_min  \
# 0        18       4            ORD       21       4      52      47
# 2        13       4            JFK       14       4      34      51
# 4        11       4            MCO       14       4      35      20
# 6        18       5            ORD       21       5      52      47
# 8        13       5            JFK       14       5      25      41
# 10       13       5            MCO       16       5      35      25
# 11       18       6            ORD       21       6      52      47
# 13       13       6            JFK       14       6      35      51
# 15       11       6            MCO       13       6       5      50
# 17       18       0            ORD       21       0      52      47
# 19       13       0            JFK       14       0      35      51
# 21       11       0            MCO       14       0      35      20
#
#     arr_clouds  arr_dewpt  arr_precip  ...  dep_precip  dep_pres  dep_rh  \
# 0           69       8.00        0.50  ...        0.00    996.50      35
# 2           84       7.20        0.50  ...        0.00  1,019.50      58
# 4           84       7.20        0.50  ...        0.00  1,015.00      58
# 6           23      -2.40        0.00  ...        0.00    994.00      40
# 8           71      -1.20        0.00  ...        0.00  1,014.50      46
# 10          58      -1.60        0.00  ...        0.00  1,014.00      42
# 11           9      -2.90        0.00  ...        0.00    990.50      35
# 13          44      -3.10        0.00  ...        0.00  1,013.50      38
# 15          48      -2.80        0.00  ...        0.00  1,013.00      60
# 17          10      -4.70        0.00  ...        0.00    987.00      36
# 19          10      -4.80        0.00  ...        0.00  1,012.50      39
# 21          10      -4.80        0.00  ...        0.12  1,011.50      76
#
#     dep_snow  dep_temp  dep_vis  dep_weather.code  dep_wind_dir  \
# 0          0     12.70    24.00               801           280
# 2          0     12.10    24.00               804           110
# 4          0     28.10    24.00               801           280
# 6          0      9.70    24.13               803           296
# 8          0     15.80    24.00               803           283
# 10         0     30.60    24.00               801           270
# 11         0     13.70    24.13               801           273
# 13         0     12.80    24.13               803           256
# 15         0     27.20    24.13               802           230
# 17         0     16.00    24.13               804           203
# 19         0     14.60    24.13               802           276
# 21         0     24.60     7.24               803           255
#
#     dep_wind_gust_spd  dep_wind_spd
# 0               12.50          8.40
# 2                7.20          5.20
# 4                2.40          2.00
# 6                6.66          4.40
# 8                5.73          4.13
# 10               4.80          3.46
# 11               9.03          6.00
# 13               7.93          5.20
# 15               5.20          3.60
# 17               8.68          5.77
# 19               6.06          4.06
# 21               8.00          5.18
#
# [12 rows x 31 columns]

# %%
pred_data2.head(20)
# Out:
#    dep_hour dep_day Origin_Airport arr_hour arr_day dep_min arr_min  \
# 1        19       4            ORD       22       4      59      52
# 3        14       4            JFK       16       4      55      21
# 5        13       4            MCO       16       4      35      25
# 7        19       5            ORD       22       5      59      52
# 9        14       5            JFK       16       5      55      21
# 12       19       6            ORD       22       6      59      52
# 14       14       6            JFK       16       6      55      21
# 16       13       6            MCO       16       6      35      25
# 18       19       0            ORD       22       0      59      52
# 20       14       0            JFK       16       0      55      21
# 22       13       0            MCO       16       0      34      25
#
#     arr_clouds  arr_dewpt  arr_precip  ...  dep_precip  dep_pres  dep_rh  \
# 1           66       7.20        0.25  ...        0.00    996.50      37
# 3           86       7.90        0.76  ...        0.00  1,019.00      59
# 5           86       7.90        0.76  ...        0.00  1,013.50      45
# 7           23      -2.40        0.00  ...        0.00    994.50      41
# 9           58      -1.60        0.00  ...        0.00  1,014.00      42
# 12           9      -2.90        0.00  ...        0.00    990.50      36
# 14          32      -3.20        0.00  ...        0.00  1,012.50      37
# 16          32      -3.20        0.00  ...        0.00  1,012.00      49
# 18          13      -4.30        0.00  ...        0.00    986.50      36
# 20           9      -4.60        0.00  ...        0.00  1,012.00      36
# 22           9      -4.60        0.00  ...        0.20  1,011.00      66
#
#     dep_snow  dep_temp  dep_vis  dep_weather.code  dep_wind_dir  \
# 1          0     12.10    24.00               803           280
# 3          0     12.30    24.00               804           120
# 5          0     30.90    24.00               801           270
# 7          0      9.50    24.13               804           300
# 9          0     16.50    24.00               803           270
# 12         0     13.40    24.13               801           270
# 14         0     13.40    24.13               803           250
# 16         0     30.00    24.13               802           236
# 18         0     15.90    24.13               804           200
# 20         0     15.70    24.13               801           270
# 22         0     26.70    24.13               803           271
#
#     dep_wind_gust_spd  dep_wind_spd
# 1               11.10          7.60
# 3                7.30          5.60
# 5                3.20          2.40
# 7                6.00          4.00
# 9                6.00          4.40
# 12               9.10          6.00
# 14               8.70          5.60
# 16               8.33          5.46
# 18               8.80          5.87
# 20               6.10          4.10
# 22               9.39          6.05
#
# [11 rows x 31 columns]

# %%
pred_data1.to_csv('pred_data1.csv')

# %%
len(pred_data1)
# Out:
# 12

# %%
pred_data1.head(20)
# Out:
#    dep_hour dep_day Origin_Airport arr_hour arr_day dep_min arr_min  \
# 0        18       4            ORD       21       4      52      47
# 2        13       4            JFK       14       4      34      51
# 4        11       4            MCO       14       4      35      20
# 6        18       5            ORD       21       5      52      47
# 8        13       5            JFK       14       5      25      41
# 10       13       5            MCO       16       5      35      25
# 11       18       6            ORD       21       6      52      47
# 13       13       6            JFK       14       6      35      51
# 15       11       6            MCO       13       6       5      50
# 17       18       0            ORD       21       0      52      47
# 19       13       0            JFK       14       0      35      51
# 21       11       0            MCO       14       0      35      20
#
#     arr_clouds  arr_dewpt  arr_precip  ...  dep_precip  dep_pres  dep_rh  \
# 0           69       8.00        0.50  ...        0.00    996.50      35
# 2           84       7.20        0.50  ...        0.00  1,019.50      58
# 4           84       7.20        0.50  ...        0.00  1,015.00      58
# 6           23      -2.40        0.00  ...        0.00    994.00      40
# 8           71      -1.20        0.00  ...        0.00  1,014.50      46
# 10          58      -1.60        0.00  ...        0.00  1,014.00      42
# 11           9      -2.90        0.00  ...        0.00    990.50      35
# 13          44      -3.10        0.00  ...        0.00  1,013.50      38
# 15          48      -2.80        0.00  ...        0.00  1,013.00      60
# 17          10      -4.70        0.00  ...        0.00    987.00      36
# 19          10      -4.80        0.00  ...        0.00  1,012.50      39
# 21          10      -4.80        0.00  ...        0.12  1,011.50      76
#
#     dep_snow  dep_temp  dep_vis  dep_weather.code  dep_wind_dir  \
# 0          0     12.70    24.00               801           280
# 2          0     12.10    24.00               804           110
# 4          0     28.10    24.00               801           280
# 6          0      9.70    24.13               803           296
# 8          0     15.80    24.00               803           283
# 10         0     30.60    24.00               801           270
# 11         0     13.70    24.13               801           273
# 13         0     12.80    24.13               803           256
# 15         0     27.20    24.13               802           230
# 17         0     16.00    24.13               804           203
# 19         0     14.60    24.13               802           276
# 21         0     24.60     7.24               803           255
#
#     dep_wind_gust_spd  dep_wind_spd
# 0               12.50          8.40
# 2                7.20          5.20
# 4                2.40          2.00
# 6                6.66          4.40
# 8                5.73          4.13
# 10               4.80          3.46
# 11               9.03          6.00
# 13               7.93          5.20
# 15               5.20          3.60
# 17               8.68          5.77
# 19               6.06          4.06
# 21               8.00          5.18
#
# [12 rows x 31 columns]

# %%
pred_data2.to_csv('pred_data2.csv')

# %%
len(pred_data2)
# Out:
# 11
